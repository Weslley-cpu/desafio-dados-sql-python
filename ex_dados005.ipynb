# %%
import pandas as pd
df = pd.read_csv('text.csv')
df2 = pd.read_csv('text2.csv')
df3 = pd.read_csv('text3.csv')
display(df)
display(df2)
display(df3)
# Out:
#      ID_Pedido  Data_Venda  ID_Loja  ID_Produto  ID_Cliente  Qtd_Vendida  \
# 0            1  2019-01-01        2           4          16            1
# 1            2  2019-01-01        1           4          17            1
# 2            3  2019-01-01        3           4          23            1
# 3            4  2019-01-01        8           4          24            1
# 4            5  2019-01-01        4           4          25            1
# ..         ...         ...      ...         ...         ...          ...
# 369        370  2019-12-14        6           8          31            1
# 370        371  2019-12-14        7           8          78            1
# 371        372  2019-12-20        1           8          78            1
# 372        373  2019-12-24        4           8           4            1
# 373        374  2019-12-24        7           8          55            1
#
#      Receita_Venda  Custo_Venda  Custo_Unit  Preco_Unit
# ...

# %%
df3 = df3.drop(columns=['Telefone'])
df = df.drop(columns=['Preco_Unit'])
display(df)
display(df3)
df['Faturamento_Venda'] = df['Receita_Venda'] * df['Qtd_Vendida']
display(df)
# Out:
#      ID_Pedido  Data_Venda  ID_Loja  ID_Produto  ID_Cliente  Qtd_Vendida  \
# 0            1  2019-01-01        2           4          16            1
# 1            2  2019-01-01        1           4          17            1
# 2            3  2019-01-01        3           4          23            1
# 3            4  2019-01-01        8           4          24            1
# 4            5  2019-01-01        4           4          25            1
# ..         ...         ...      ...         ...         ...          ...
# 369        370  2019-12-14        6           8          31            1
# 370        371  2019-12-14        7           8          78            1
# 371        372  2019-12-20        1           8          78            1
# 372        373  2019-12-24        4           8           4            1
# 373        374  2019-12-24        7           8          55            1
#
#      Receita_Venda  Custo_Venda  Custo_Unit
# 0              350        129.5       129.5
# ...

# %%
df.to_excel('text.xlsx', index=False)
df2.to_excel('text2.xlsx', index=False)
df3.to_excel('text3.xlsx', index=False)
